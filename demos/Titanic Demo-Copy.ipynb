# %% [markdown]
# # EvalML Titanic Demo:
# This demo shows how easy it is to create machine learning mdels using EvalML on the classic Titanic dataset.
# The Titanic dataset includes information on each passenger, such as the cost of fare, sex, age, passenger class,
# and most importantly, whether they survived the Titanic.
#
# Data from: https://www.kaggle.com/c/titanic

# %%
# import libraries
import os
import evalml
import numpy as np
import pandas as pd

# %%
# import titantic dataset
titanic_train = pd.read_csv('https://featuretools-static.s3.amazonaws.com/evalml/Titanic/train.csv')

display(titanic_train.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Missing data:
# As the dataset includes passengers with missing data, we fill the missing values with appropriate data.
# Here we fill the missing ages with the mean age and the embarked location with the mode.

# %%
# fill missing data
titanic_train["Age"].fillna(titanic_train["Age"].mean(skipna=True), 
                            inplace=True)
titanic_train["Embarked"].fillna(titanic_train["Embarked"].mode()[0], 
                              inplace=True)

titanic_train.drop('Cabin', axis=1, inplace=True)
titanic_train.drop('Name', axis=1, inplace=True)
titanic_train.drop('Ticket', axis=1, inplace=True)
titanic_train.drop('PassengerId', axis=1, inplace=True)

# %%
# check if any is NaN
print(titanic_train.isnull().any(axis=1).any())
# Out:
# False

# %% [markdown]
# ## Encoding Categorical Variables
# Many machine learning algorithms are not compatible with categorical values. Here we encode these categorical variables into numerical ones by creating dummy variables.

# %%
# create encodings
titanic_train = pd.get_dummies(titanic_train, columns=["Pclass"])
titanic_train = pd.get_dummies(titanic_train, columns=["Embarked"])
titanic_train = pd.get_dummies(titanic_train, columns=["Sex"])
titanic_train.drop('Sex_female', axis=1, inplace=True)

# %%
X_train = titanic_train.drop('Survived', axis=1)
y_train = titanic_train['Survived']

display(X_train.head())
# Out:
#     Age  SibSp  Parch     Fare  Pclass_1  Pclass_2  Pclass_3  Embarked_C  \
# 0  22.0      1      0   7.2500         0         0         1           0
# 1  38.0      1      0  71.2833         1         0         0           1
# 2  26.0      0      0   7.9250         0         0         1           0
# 3  35.0      1      0  53.1000         1         0         0           0
# 4  35.0      0      0   8.0500         0         0         1           0
#
#    Embarked_Q  Embarked_S  Sex_male
# 0           0           1         1
# 1           0           0         0
# 2           0           1         0
# 3           0           1         0
# 4           0           1         1

# %% [markdown]
# ## Model Training:
# After creating a train/test split to validate our model. We utilize EvalML to automatically search over 50 models, for not only the most accurate type of model but also the model with the most accurate parameters. It is as easy as calling `clf.fit()` on your data!

# %%
X_train, X_holdout, y_train, y_holdout = evalml.preprocessing.split_data(X_train, y_train, test_size=.2)

# %%
# use evalml
clf = evalml.AutoClassifier(objective="precision",
                            max_pipelines=50)

# %%
# fit using autoclassfier
clf.fit(X_train, y_train)
# Out:
# *****************************
# * Beginning pipeline search *
# *****************************
#
# Optimizing for Precision. Greater score is better.
#
# Searching up to 50 pipelines. No time limit is set. Set one using max_time parameter.
#
# Possible model types: random_forest, xgboost, linear_model
#
# Testing Random Forest w/ imputation: 100%|██████████| 50/50 [05:34<00:00,  6.69s/it]
#
# ✔ Optimization finished

# %%
clf.rankings
# Out:
#     id               pipeline_name     score  high_variance_cv  \
# 0   29             XGBoostPipeline  0.775000             False
# 1   37             XGBoostPipeline  0.768293             False
# 2    7             XGBoostPipeline  0.758621             False
# 3   34             XGBoostPipeline  0.750000             False
# 4   38             XGBoostPipeline  0.750000             False
# 5   45             XGBoostPipeline  0.750000             False
# 6    2             XGBoostPipeline  0.743590             False
# 7   39             XGBoostPipeline  0.741176             False
# 8    5             XGBoostPipeline  0.733333             False
# 9   42    RFClassificationPipeline  0.717391             False
# 10  40    RFClassificationPipeline  0.717391             False
# 11  44    RFClassificationPipeline  0.717391             False
# 12  46    RFClassificationPipeline  0.717391             False
# 13  33             XGBoostPipeline  0.715909             False
# 14  32             XGBoostPipeline  0.715909             False
# 15   1    RFClassificationPipeline  0.714286             False
# 16   6             XGBoostPipeline  0.712500             False
# 17  15             XGBoostPipeline  0.712500             False
# 18  20             XGBoostPipeline  0.712500             False
# 19  30             XGBoostPipeline  0.712500             False
# 20   8    RFClassificationPipeline  0.709677             False
# 21  35    RFClassificationPipeline  0.709677             False
# 22  22    RFClassificationPipeline  0.709677             False
# 23  31             XGBoostPipeline  0.707865             False
# 24  47    RFClassificationPipeline  0.706522             False
# 25  26    RFClassificationPipeline  0.702128             False
# 26   0    RFClassificationPipeline  0.698925             False
# 27  25    RFClassificationPipeline  0.698925             False
# 28  14             XGBoostPipeline  0.698795             False
# 29  28    RFClassificationPipeline  0.694737             False
# 30  48    RFClassificationPipeline  0.687500             False
# 31  21    RFClassificationPipeline  0.687500             False
# 32  41    RFClassificationPipeline  0.677083             False
# 33  49    RFClassificationPipeline  0.677083             False
# 34  11  LogisticRegressionPipeline  0.670330             False
# 35  24  LogisticRegressionPipeline  0.670330             False
# 36  10    RFClassificationPipeline  0.670000             False
# 37   3    RFClassificationPipeline  0.670000             False
# 38  18  LogisticRegressionPipeline  0.666667             False
# 39  17  LogisticRegressionPipeline  0.666667             False
# 40  16  LogisticRegressionPipeline  0.666667             False
# 41  19  LogisticRegressionPipeline  0.666667             False
# 42  12  LogisticRegressionPipeline  0.666667             False
# 43  23  LogisticRegressionPipeline  0.666667             False
# 44  43  LogisticRegressionPipeline  0.666667             False
# 45   9  LogisticRegressionPipeline  0.666667             False
# 46   4  LogisticRegressionPipeline  0.666667             False
# 47  13  LogisticRegressionPipeline  0.666667             False
# 48  27             XGBoostPipeline  0.663265             False
# 49  36    RFClassificationPipeline  0.576087             False
#
#                                            parameters
# 0   {'eta': 0.35950790057378607, 'min_child_weight...
# 1   {'eta': 0.009150580761498219, 'min_child_weigh...
# 2   {'eta': 0.6481718720511973, 'min_child_weight'...
# 3   {'eta': 0.18166317747775154, 'min_child_weight...
# 4   {'eta': 0.0038098661671809317, 'min_child_weig...
# 5   {'eta': 0.023692548385559904, 'min_child_weigh...
# 6   {'eta': 0.5928446182250184, 'min_child_weight'...
# 7   {'eta': 0.1422726331411999, 'min_child_weight'...
# 8   {'eta': 0.38438170729269994, 'min_child_weight...
# 9   {'n_estimators': 970, 'max_depth': 422, 'imput...
# 10  {'n_estimators': 985, 'max_depth': 417, 'imput...
# 11  {'n_estimators': 972, 'max_depth': 395, 'imput...
# 12  {'n_estimators': 970, 'max_depth': 388, 'imput...
# 13  {'eta': 0.46348747172713256, 'min_child_weight...
# 14  {'eta': 0.2460229098861177, 'min_child_weight'...
# 15  {'n_estimators': 369, 'max_depth': 10, 'impute...
# 16  {'eta': 0.5288949197529046, 'min_child_weight'...
# 17  {'eta': 0.7206326547259169, 'min_child_weight'...
# 18  {'eta': 0.264555612104627, 'min_child_weight':...
# 19  {'eta': 0.6531400357979378, 'min_child_weight'...
# 20  {'n_estimators': 715, 'max_depth': 487, 'imput...
# 21  {'n_estimators': 919, 'max_depth': 98, 'impute...
# 22  {'n_estimators': 857, 'max_depth': 432, 'imput...
# 23  {'eta': 0.41030156269012574, 'min_child_weight...
# 24  {'n_estimators': 989, 'max_depth': 409, 'imput...
# 25  {'n_estimators': 433, 'max_depth': 289, 'imput...
# 26  {'n_estimators': 569, 'max_depth': 630, 'imput...
# 27  {'n_estimators': 187, 'max_depth': 756, 'imput...
# 28  {'eta': 0.9786183422327642, 'min_child_weight'...
# 29  {'n_estimators': 554, 'max_depth': 544, 'imput...
# 30  {'n_estimators': 994, 'max_depth': 413, 'imput...
# 31  {'n_estimators': 926, 'max_depth': 116, 'imput...
# 32  {'n_estimators': 934, 'max_depth': 262, 'imput...
# 33  {'n_estimators': 978, 'max_depth': 756, 'imput...
# 34  {'penalty': 'l2', 'C': 0.5765626434012575, 'im...
# 35  {'penalty': 'l2', 'C': 0.44486185482223584, 'i...
# 36  {'n_estimators': 859, 'max_depth': 678, 'imput...
# 37  {'n_estimators': 609, 'max_depth': 71, 'impute...
# 38  {'penalty': 'l2', 'C': 5.209570020716537, 'imp...
# 39  {'penalty': 'l2', 'C': 8.702171711000782, 'imp...
# 40  {'penalty': 'l2', 'C': 3.6887329830070748, 'im...
# 41  {'penalty': 'l2', 'C': 5.824377722830321, 'imp...
# 42  {'penalty': 'l2', 'C': 8.123565600467177, 'imp...
# 43  {'penalty': 'l2', 'C': 1.0680169958060437, 'im...
# 44  {'penalty': 'l2', 'C': 1.0370250731510569, 'im...
# 45  {'penalty': 'l2', 'C': 6.239401330891865, 'imp...
# 46  {'penalty': 'l2', 'C': 8.444214828324364, 'imp...
# 47  {'penalty': 'l2', 'C': 8.362426847738403, 'imp...
# 48  {'eta': 0.1496748671836832, 'min_child_weight'...
# 49  {'n_estimators': 978, 'max_depth': 415, 'imput...

# %% [markdown]
# ### Here we can see how the top ranked model scored in terms of prescision on the holdout set!

# %%
pipeline = clf.best_pipeline
print("Best model score: {}".format(pipeline.score(X_holdout, y_holdout)))
# Out:
# Best model score: 0.7777777777777778
