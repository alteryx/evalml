# %% [markdown]
# # Exploring search results
#
# After finishing a pipeline search, we can inspect the results. First, let's build a search of 10 different pipelines to explore.

# %%
import evalml

X, y = evalml.demos.load_breast_cancer()

clf = evalml.AutoClassifier(objective="f1",
                            max_pipelines=10)

clf.fit(X, y)
# Out:
# *****************************
# * Beginning pipeline search *
# *****************************
#
# Optimizing for F1. Greater score is better.
#
# Searching up to 10 pipelines. No time limit is set. Set one using max_time parameter.
#
# Possible model types: random_forest, xgboost, linear_model
#
# Testing LogisticRegression w/ imputation + scaling: 100%|██████████| 10/10 [00:23<00:00,  2.37s/it]
#
# ✔ Optimization finished

# %% [markdown]
# ## View Rankings
# A summary of all the pipelines built can be returned as a dataframe. It is sorted by score. EvalML knows based on your objective function whether or not high or lower is better.

# %%
clf.rankings
# Out:
#    id               pipeline_name     score  high_variance_cv  \
# 0   8  LogisticRegressionPipeline  0.975410             False
# 1   7  LogisticRegressionPipeline  0.974359             False
# 2   9  LogisticRegressionPipeline  0.974359             False
# 3   4  LogisticRegressionPipeline  0.970464             False
# 4   0    RFClassificationPipeline  0.906250             False
# 5   2    RFClassificationPipeline  0.906250             False
# 6   1             XGBoostPipeline  0.901961             False
# 7   3             XGBoostPipeline  0.901961             False
# 8   5             XGBoostPipeline  0.901961             False
# 9   6             XGBoostPipeline  0.901961             False
#
#                                           parameters
# 0  {'penalty': 'l2', 'C': 0.5765626434012575, 'im...
# 1  {'penalty': 'l2', 'C': 6.239401330891865, 'imp...
# 2  {'penalty': 'l2', 'C': 8.123565600467177, 'imp...
# 3  {'penalty': 'l2', 'C': 8.444214828324364, 'imp...
# 4  {'n_estimators': 569, 'max_depth': 630, 'imput...
# 5  {'n_estimators': 369, 'max_depth': 10, 'impute...
# 6  {'eta': 0.5928446182250184, 'min_child_weight'...
# 7  {'eta': 0.38438170729269994, 'min_child_weight...
# 8  {'eta': 0.5288949197529046, 'min_child_weight'...
# 9  {'eta': 0.6481718720511973, 'min_child_weight'...

# %% [markdown]
# ## Describe Pipeline
# Each pipeline is given an `id`. We can get more information about any particular pipeline using that id

# %%
clf.describe_pipeline(0)
# Out:
# ************************
# * Pipeline Description *
# ************************
#
# Pipeline Name: Random Forest w/ imputation
# Model type: random_forest
# Objective: F1 (greater is better)
# Total training time (including CV): 9.6 seconds
#
# Parameters
# ==========
# • n_estimators: 569
# • max_depth: 630
# • impute_strategy: most_frequent
# • percent_features: 0.8593661614465293
#
# Cross Validation
# =================
#         F1  Precision  Recall   AUC  Log Loss
# 0    0.906      0.847   0.906 0.840     4.363
# 1    0.907      0.875   0.907 0.858     4.181
# 2    0.912      0.954   0.912 0.901     3.655
# mean 0.908      0.892   0.908 0.866     4.066
# std  0.003      0.056   0.003 0.032     0.368

# %% [markdown]
# ## Get Pipeline
# You can get the object for any pipeline as well

# %%
clf.get_pipeline(0)

# %% [markdown]
# ### Get best pipeline
# If you specifically want to get the best pipeline, there is a convienient access.

# %%
clf.best_pipeline

# %% [markdown]
# ## Access raw results
# You can also get access to all the underlying data like this

# %%
clf.results
# Out:
# {0: {'id': 0,
#   'pipeline_name': 'RFClassificationPipeline',
#   'parameters': {'n_estimators': 569,
#    'max_depth': 630,
#    'impute_strategy': 'most_frequent',
#    'percent_features': 0.8593661614465293},
#   'score': 0.90625,
#   'high_variance_cv': False,
#   'scores': [0.90625, 0.9068825910931174, 0.912280701754386],
#   'all_objective_scores': [{'F1': 0.90625,
#     'Precision': 0.8467153284671532,
#     'Recall': 0.90625,
#     'AUC': 0.8395076340395313,
#     'Log Loss': 4.362881184336267},
#    {'F1': 0.9068825910931174,
#     'Precision': 0.875,
#     'Recall': 0.9068825910931174,
#     'AUC': 0.8579121789560895,
#     'Log Loss': 4.1810771086412055},
#    {'F1': 0.912280701754386,
#     'Precision': 0.9541284403669725,
#     'Recall': 0.912280701754386,
#     'AUC': 0.9012605042016808,
#     'Log Loss': 3.654918126377591}],
#   'training_time': 9.602061033248901},
#  1: {'id': 1,
#   'pipeline_name': 'XGBoostPipeline',
#   'parameters': {'eta': 0.5928446182250184,
#    'min_child_weight': 8.598391737229157,
#    'max_depth': 4,
#    'impute_strategy': 'most_frequent',
#    'percent_features': 0.6273280598181127},
#   'score': 0.9019607843137255,
#   'high_variance_cv': False,
#   'scores': [0.9019607843137255, 0.9163346613545816, 0.9217391304347827],
#   'all_objective_scores': [{'F1': 0.9019607843137255,
#     'Precision': 0.8455882352941176,
#     'Recall': 0.9019607843137255,
#     'AUC': 0.8353059533672623,
#     'Log Loss': 4.544664217993692},
#    {'F1': 0.9163346613545816,
#     'Precision': 0.8712121212121212,
#     'Recall': 0.9163346613545816,
#     'AUC': 0.8634749674517695,
#     'Log Loss': 3.8175152497338827},
#    {'F1': 0.9217391304347827,
#     'Precision': 0.954954954954955,
#     'Recall': 0.9217391304347827,
#     'AUC': 0.9096638655462185,
#     'Log Loss': 3.28942842907695}],
#   'training_time': 0.3488330841064453},
#  2: {'id': 2,
#   'pipeline_name': 'RFClassificationPipeline',
#   'parameters': {'n_estimators': 369,
#    'max_depth': 10,
#    'impute_strategy': 'median',
#    'percent_features': 0.39053789021977287},
#   'score': 0.90625,
#   'high_variance_cv': False,
#   'scores': [0.90625, 0.9068825910931174, 0.912280701754386],
#   'all_objective_scores': [{'F1': 0.90625,
#     'Precision': 0.8467153284671532,
#     'Recall': 0.90625,
#     'AUC': 0.8395076340395313,
#     'Log Loss': 4.362881184336267},
#    {'F1': 0.9068825910931174,
#     'Precision': 0.875,
#     'Recall': 0.9068825910931174,
#     'AUC': 0.8579121789560895,
#     'Log Loss': 4.1810771086412055},
#    {'F1': 0.912280701754386,
#     'Precision': 0.9541284403669725,
#     'Recall': 0.912280701754386,
#     'AUC': 0.9012605042016808,
#     'Log Loss': 3.654918126377591}],
#   'training_time': 7.4244420528411865},
#  3: {'id': 3,
#   'pipeline_name': 'XGBoostPipeline',
#   'parameters': {'eta': 0.38438170729269994,
#    'min_child_weight': 3.677811458900251,
#    'max_depth': 13,
#    'impute_strategy': 'median',
#    'percent_features': 0.793807787701838},
#   'score': 0.9019607843137255,
#   'high_variance_cv': False,
#   'scores': [0.9019607843137255, 0.9163346613545816, 0.9264069264069265],
#   'all_objective_scores': [{'F1': 0.9019607843137255,
#     'Precision': 0.8455882352941176,
#     'Recall': 0.9019607843137255,
#     'AUC': 0.8353059533672623,
#     'Log Loss': 4.544664217993692},
#    {'F1': 0.9163346613545816,
#     'Precision': 0.8712121212121212,
#     'Recall': 0.9163346613545816,
#     'AUC': 0.8634749674517695,
#     'Log Loss': 3.8175152497338827},
#    {'F1': 0.9264069264069265,
#     'Precision': 0.9553571428571429,
#     'Recall': 0.9264069264069265,
#     'AUC': 0.9138655462184874,
#     'Log Loss': 3.1066835804266284}],
#   'training_time': 0.8000447750091553},
#  4: {'id': 4,
#   'pipeline_name': 'LogisticRegressionPipeline',
#   'parameters': {'penalty': 'l2',
#    'C': 8.444214828324364,
#    'impute_strategy': 'most_frequent'},
#   'score': 0.970464135021097,
#   'high_variance_cv': False,
#   'scores': [0.970464135021097, 0.9754098360655737, 0.9743589743589743],
#   'all_objective_scores': [{'F1': 0.970464135021097,
#     'Precision': 0.9745762711864406,
#     'Recall': 0.970464135021097,
#     'AUC': 0.9620665167475442,
#     'Log Loss': 1.2724938608245555},
#    {'F1': 0.9754098360655737,
#     'Precision': 0.952,
#     'Recall': 0.9754098360655737,
#     'AUC': 0.9577464788732395,
#     'Log Loss': 1.090723452389713},
#    {'F1': 0.9743589743589743,
#     'Precision': 0.991304347826087,
#     'Recall': 0.9743589743589743,
#     'AUC': 0.9718487394957984,
#     'Log Loss': 1.096473322576161}],
#   'training_time': 2.7731189727783203},
#  5: {'id': 5,
#   'pipeline_name': 'XGBoostPipeline',
#   'parameters': {'eta': 0.5288949197529046,
#    'min_child_weight': 6.112401049845392,
#    'max_depth': 6,
#    'impute_strategy': 'most_frequent',
#    'percent_features': 0.34402219881309576},
#   'score': 0.9019607843137255,
#   'high_variance_cv': False,
#   'scores': [0.9019607843137255, 0.9163346613545816, 0.9217391304347827],
#   'all_objective_scores': [{'F1': 0.9019607843137255,
#     'Precision': 0.8455882352941176,
#     'Recall': 0.9019607843137255,
#     'AUC': 0.8353059533672623,
#     'Log Loss': 4.544664217993692},
#    {'F1': 0.9163346613545816,
#     'Precision': 0.8712121212121212,
#     'Recall': 0.9163346613545816,
#     'AUC': 0.8634749674517695,
#     'Log Loss': 3.8175152497338827},
#    {'F1': 0.9217391304347827,
#     'Precision': 0.954954954954955,
#     'Recall': 0.9217391304347827,
#     'AUC': 0.9096638655462185,
#     'Log Loss': 3.28942842907695}],
#   'training_time': 0.4946303367614746},
#  6: {'id': 6,
#   'pipeline_name': 'XGBoostPipeline',
#   'parameters': {'eta': 0.6481718720511973,
#    'min_child_weight': 4.314173858564932,
#    'max_depth': 6,
#    'impute_strategy': 'most_frequent',
#    'percent_features': 0.871312026764351},
#   'score': 0.9019607843137255,
#   'high_variance_cv': False,
#   'scores': [0.9019607843137255, 0.9163346613545816, 0.9217391304347827],
#   'all_objective_scores': [{'F1': 0.9019607843137255,
#     'Precision': 0.8455882352941176,
#     'Recall': 0.9019607843137255,
#     'AUC': 0.8353059533672623,
#     'Log Loss': 4.544664217993692},
#    {'F1': 0.9163346613545816,
#     'Precision': 0.8712121212121212,
#     'Recall': 0.9163346613545816,
#     'AUC': 0.8634749674517695,
#     'Log Loss': 3.8175152497338827},
#    {'F1': 0.9217391304347827,
#     'Precision': 0.954954954954955,
#     'Recall': 0.9217391304347827,
#     'AUC': 0.9096638655462185,
#     'Log Loss': 3.28942842907695}],
#   'training_time': 0.5107090473175049},
#  7: {'id': 7,
#   'pipeline_name': 'LogisticRegressionPipeline',
#   'parameters': {'penalty': 'l2',
#    'C': 6.239401330891865,
#    'impute_strategy': 'median'},
#   'score': 0.9743589743589743,
#   'high_variance_cv': False,
#   'scores': [0.9747899159663865, 0.9754098360655737, 0.9743589743589743],
#   'all_objective_scores': [{'F1': 0.9747899159663865,
#     'Precision': 0.9747899159663865,
#     'Recall': 0.9747899159663865,
#     'AUC': 0.9662681974198131,
#     'Log Loss': 1.0907108271671306},
#    {'F1': 0.9754098360655737,
#     'Precision': 0.952,
#     'Recall': 0.9754098360655737,
#     'AUC': 0.9577464788732395,
#     'Log Loss': 1.090723452389713},
#    {'F1': 0.9743589743589743,
#     'Precision': 0.991304347826087,
#     'Recall': 0.9743589743589743,
#     'AUC': 0.9718487394957984,
#     'Log Loss': 1.096473322576161}],
#   'training_time': 1.363401174545288},
#  8: {'id': 8,
#   'pipeline_name': 'LogisticRegressionPipeline',
#   'parameters': {'penalty': 'l2',
#    'C': 0.5765626434012575,
#    'impute_strategy': 'mean'},
#   'score': 0.9754098360655737,
#   'high_variance_cv': False,
#   'scores': [0.9874476987447698, 0.9754098360655737, 0.9787234042553192],
#   'all_objective_scores': [{'F1': 0.9874476987447698,
#     'Precision': 0.9833333333333333,
#     'Recall': 0.9874476987447698,
#     'AUC': 0.9817138122854777,
#     'Log Loss': 0.5453575177873297},
#    {'F1': 0.9754098360655737,
#     'Precision': 0.952,
#     'Recall': 0.9754098360655737,
#     'AUC': 0.9577464788732395,
#     'Log Loss': 1.090723452389713},
#    {'F1': 0.9787234042553192,
#     'Precision': 0.9913793103448276,
#     'Recall': 0.9787234042553192,
#     'AUC': 0.9760504201680673,
#     'Log Loss': 0.9137284739258401}],
#   'training_time': 0.13866877555847168},
#  9: {'id': 9,
#   'pipeline_name': 'LogisticRegressionPipeline',
#   'parameters': {'penalty': 'l2',
#    'C': 8.123565600467177,
#    'impute_strategy': 'median'},
#   'score': 0.9743589743589743,
#   'high_variance_cv': False,
#   'scores': [0.9747899159663865, 0.9754098360655737, 0.9743589743589743],
#   'all_objective_scores': [{'F1': 0.9747899159663865,
#     'Precision': 0.9747899159663865,
#     'Recall': 0.9747899159663865,
#     'AUC': 0.9662681974198131,
#     'Log Loss': 1.0907108271671306},
#    {'F1': 0.9754098360655737,
#     'Precision': 0.952,
#     'Recall': 0.9754098360655737,
#     'AUC': 0.9577464788732395,
#     'Log Loss': 1.090723452389713},
#    {'F1': 0.9743589743589743,
#     'Precision': 0.991304347826087,
#     'Recall': 0.9743589743589743,
#     'AUC': 0.9718487394957984,
#     'Log Loss': 1.096473322576161}],
#   'training_time': 0.16334295272827148}}
